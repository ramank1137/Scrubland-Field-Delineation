# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import jensenshannon
import ast

# Load histograms
df = pd.read_csv('grids_cluster_histograms.csv')


# Convert histograms into aligned probability vectors
all_keys = set()
for h in df['histogram']:
    hist_dict = ast.literal_eval(h.replace("=", ":"))
    all_keys.update(hist_dict.keys())

all_keys = sorted([int(k) for k in all_keys])
K = len(all_keys)

def normalize(hist_dict):
    vec = np.array([hist_dict.get(k, 0) for k in all_keys])
    if vec.sum() == 0:
        return np.zeros_like(vec)
    return vec / vec.sum()

df['vector'] = df['histogram'].apply(lambda h: normalize(eval(h.replace("=", ":"))))

# Compute full area distribution
full_dist = df['vector'].sum()
full_dist = full_dist / full_dist.sum()

# Greedy selection
selected = []
remaining = df.index.tolist()
p = 60

for _ in range(p):
    best_score = float('inf')
    best_idx = None

    for idx in remaining:
        subset = selected + [idx]
        combined = df.loc[subset, 'vector'].sum()
        combined = combined / combined.sum()

        score = jensenshannon(combined, full_dist)
        if score < best_score:
            best_score = score
            best_idx = idx

    selected.append(best_idx)
    remaining.remove(best_idx)

print("Selected tehsils:", df.loc[selected])
# Out:
# /tmp/ipykernel_234196/3332164177.py:3: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 1.23.1)
#   from scipy.spatial.distance import jensenshannon
# Selected tehsils:               system:index  grid_id  \
# 1036  0000000000000000040c     1846
# 122   0000000000000000007a      485
# 1839  0000000000000000072f     3531
# 775   00000000000000000307     1507
# 654   0000000000000000028e     1341
# 1619  00000000000000000653     2881
# 453   000000000000000001c5     1065
# 334   0000000000000000014e      879
# 1884  0000000000000000075c     3666
# 1730  000000000000000006c2     3197
# 947   000000000000000003b3     1724
# 720   000000000000000002d0     1437
# 179   000000000000000000b3      619
# 1699  000000000000000006a3     3077
# 1374  0000000000000000055e     2408
# 26    0000000000000000001a      213
# 953   000000000000000003b9     1730
# 1779  000000000000000006f3     3336
# 484   000000000000000001e4     1116
# 1038  0000000000000000040e     1848
# 76    0000000000000000004c      356
# 1119  0000000000000000045f     1965
# 1098  0000000000000000044a     1925
# 1855  0000000000000000073f     3592
# 1775  000000000000000006ef     3332
# 722   000000000000000002d2     1439
# 1045  00000000000000000415     1855
# 757   000000000000000002f5     1474
# 1492  000000000000000005d4     2622
# 1152  00000000000000000480     2019
# 127   0000000000000000007f      490
# 1801  00000000000000000709     3403
# 967   000000000000000003c7     1760
# 1035  0000000000000000040b     1845
# 1193  000000000000000004a9     2084
# 1222  000000000000000004c6     2113
# 376   00000000000000000178      946
# 1758  000000000000000006de     3270
# 676   000000000000000002a4     1378
# 765   000000000000000002fd     1482
# 1861  00000000000000000745     3598
# 113   00000000000000000071      476
# 98    00000000000000000062      420
# 1343  0000000000000000053f     2346
# 1137  00000000000000000471     1983
# 9     00000000000000000009       86
# 1081  00000000000000000439     1908
# 1845  00000000000000000735     3537
# 1450  000000000000000005aa     2547
# 515   00000000000000000203     1147
# 311   00000000000000000137      856
# 1178  0000000000000000049a     2045
# 1650  00000000000000000672     2946
# 1151  0000000000000000047f     2018
# 300   0000000000000000012c      820
# 738   000000000000000002e2     1455
# 1741  000000000000000006cd     3208
# 1190  000000000000000004a6     2057
# 1017  000000000000000003f9     1827
# 254   000000000000000000fe      749
#
#                                               histogram  \
# 1178  {29=168.0, 25=50.0, 4=23539.298039215682, 12=1...
# 1650  {29=163.0, 25=181192.53725490105, 4=28.5058823...
# 1151  {29=9928.298039215691, 25=148.0, 4=1698.741176...
# 300   {29=104.2392156862745, 25=212.0, 4=2037.305882...
# 738   {29=314.0, 25=2361.50588235294, 4=89515.215686...
# 1741  {29=1897.7019607843135, 25=453.0, 4=10776.6431...
# 1190  {29=30424.45882352945, 2=8133.082352941186, 27...
# 1017  {29=2492.686274509806, 25=84691.89803921628, 6...
# 254   {29=1836.9960784313726, 25=157491.6862745098, ...
#
#                                                    .geo  \
# 1036  {"type":"Polygon","coordinates":[[[79.25811766...
# 122   {"type":"Polygon","coordinates":[[[79.60968013...
# 1839  {"type":"Polygon","coordinates":[[[78.81866457...
# 775   {"type":"Polygon","coordinates":[[[78.02764889...
# 654   {"type":"Polygon","coordinates":[[[80.57647702...
# 1619  {"type":"Polygon","coordinates":[[[78.81866457...
# 453   {"type":"Polygon","coordinates":[[[79.17022704...
# 334   {"type":"Polygon","coordinates":[[[79.96124266...
# 1884  {"type":"Polygon","coordinates":[[[79.25811766...
# 1730  {"type":"Polygon","coordinates":[[[78.02764889...
# 947   {"type":"Polygon","coordinates":[[[79.96124266...
# 720   {"type":"Polygon","coordinates":[[[77.58819577...
# 179   {"type":"Polygon","coordinates":[[[79.96124266...
# 1699  {"type":"Polygon","coordinates":[[[78.90655516...
# 1374  {"type":"Polygon","coordinates":[[[77.23663327...
# 26    {"type":"Polygon","coordinates":[[[78.55499269...
# 953   {"type":"Polygon","coordinates":[[[80.48858646...
# 1779  {"type":"Polygon","coordinates":[[[78.81866457...
# 484   {"type":"Polygon","coordinates":[[[77.93975830...
# 1038  {"type":"Polygon","coordinates":[[[79.43389889...
# 76    {"type":"Polygon","coordinates":[[[79.69757084...
# 1119  {"type":"Polygon","coordinates":[[[78.29132082...
# 1098  {"type":"Polygon","coordinates":[[[80.48858646...
# 1855  {"type":"Polygon","coordinates":[[[78.46710208...
# 1775  {"type":"Polygon","coordinates":[[[78.46710208...
# 722   {"type":"Polygon","coordinates":[[[77.76397706...
# 1045  {"type":"Polygon","coordinates":[[[80.04913333...
# 757   {"type":"Polygon","coordinates":[[[80.84014895...
# 1492  {"type":"Polygon","coordinates":[[[78.90655516...
# 1152  {"type":"Polygon","coordinates":[[[77.32452388...
# 127   {"type":"Polygon","coordinates":[[[80.04913333...
# 1801  {"type":"Polygon","coordinates":[[[78.99444583...
# 967   {"type":"Polygon","coordinates":[[[77.41241453...
# 1035  {"type":"Polygon","coordinates":[[[79.17022704...
# 1193  {"type":"Polygon","coordinates":[[[77.32452388...
# 1222  {"type":"Polygon","coordinates":[[[79.87335201...
# 376   {"type":"Polygon","coordinates":[[[80.13702393...
# 1758  {"type":"Polygon","coordinates":[[[78.73077392...
# 676   {"type":"Polygon","coordinates":[[[78.11553953...
# 765   {"type":"Polygon","coordinates":[[[81.54327389...
# 1861  {"type":"Polygon","coordinates":[[[78.99444583...
# 113   {"type":"Polygon","coordinates":[[[78.81866457...
# 98    {"type":"Polygon","coordinates":[[[79.60968013...
# 1343  {"type":"Polygon","coordinates":[[[77.50030516...
# 1137  {"type":"Polygon","coordinates":[[[79.87335201...
# 9     {"type":"Polygon","coordinates":[[[78.81866457...
# 1081  {"type":"Polygon","coordinates":[[[78.99444583...
# 1845  {"type":"Polygon","coordinates":[[[79.34600833...
# 1450  {"type":"Polygon","coordinates":[[[78.02764889...
# 515   {"type":"Polygon","coordinates":[[[80.66436767...
# 311   {"type":"Polygon","coordinates":[[[77.93975830...
# 1178  {"type":"Polygon","coordinates":[[[79.60968013...
# 1650  {"type":"Polygon","coordinates":[[[78.81866457...
# 1151  {"type":"Polygon","coordinates":[[[77.23663327...
# 300   {"type":"Polygon","coordinates":[[[80.48858646...
# 738   {"type":"Polygon","coordinates":[[[79.17022704...
# 1741  {"type":"Polygon","coordinates":[[[78.99444583...
# 1190  {"type":"Polygon","coordinates":[[[80.66436767...
# 1017  {"type":"Polygon","coordinates":[[[77.58819577...
# 254   {"type":"Polygon","coordinates":[[[79.96124266...
#
#                                                  vector
# 1036  [0.00018211922066971737, 0.07362172173797141, ...
# 122   [0.0, 1.3630119353120018e-05, 0.0, 0.121505997...
# 1839  [0.012647947772517562, 0.03782476219319856, 0....
# 775   [0.0, 0.0, 0.0, 0.00040331408174510314, 0.0, 0...
# 654   [0.010845076082134213, 2.8258973925300744e-05,...
# 1619  [1.3088995063719982e-05, 0.16386901403429296, ...
# 453   [0.0, 0.0, 0.0, 0.027868278971868832, 0.017213...
# 334   [9.3259980031288e-06, 0.0, 0.0, 0.117948817324...
# 1884  [0.08376462582810029, 0.021301877515798984, 0....
# 1730  [0.0, 5.495230238923052e-05, 0.0, 5.0372943856...
# 947   [0.007004944585364797, 0.0641575407641059, 0.0...
# 720   [0.0, 0.0, 0.0, 0.003842017992943084, 0.0, 0.1...
# 179   [8.698409092208946e-05, 0.0, 0.0, 0.1123963900...
# 1699  [4.713134019721721e-05, 0.1692616598754994, 0....
# 1374  [0.0, 0.0, 0.0, 0.0010312758173582322, 0.00022...
# 26    [0.00036714612889802414, 0.0, 0.0, 0.102036034...
# 953   [0.052798957543832625, 0.0003718084946649624, ...
# 1779  [0.00029412503864893015, 0.08898213061287223, ...
# 484   [0.0, 0.0, 0.0, 0.0014433638791015852, 3.34783...
# 1038  [5.601237835780816e-06, 0.057363950457890445, ...
# 76    [0.0, 0.0, 0.0, 0.05504958320272985, 0.0088909...
# 1119  [0.0, 0.0, 0.0, 0.001795391844628946, 0.000657...
# 1098  [0.06693365411514068, 8.120045659066543e-05, 0...
# 1855  [0.002893889877487077, 0.082623810981594, 0.06...
# 1775  [0.00014015394145918658, 0.05055503766094841, ...
# 722   [0.0, 0.0, 0.0, 0.006305041831350174, 8.658868...
# 1045  [0.0006320525169121232, 0.06188072658826983, 0...
# 757   [0.2405009847102654, 0.0, 0.0, 0.0560202654110...
# 1492  [0.0, 0.05310882224406069, 0.02611815656544331...
# 1152  [0.0, 0.0, 0.0, 0.000543027306734692, 0.003689...
# 127   [1.1386083184348302e-06, 0.0, 0.0, 0.196199404...
# 1801  [0.00038823901573464354, 0.15247285794944146, ...
# 967   [0.0, 0.0, 0.0, 0.00010407042199796818, 3.4169...
# 1035  [0.0, 0.04960802300060285, 0.00376719996808139...
# 1193  [0.0003942384747486438, 0.0, 0.0, 0.0158496833...
# 1222  [0.0009801329067506144, 0.015144314887342485, ...
# 376   [0.0, 0.0, 0.0, 0.0022850269098421538, 0.00025...
# 1758  [1.1335970029580112e-06, 0.10002260703607391, ...
# 676   [0.0, 0.0, 0.0, 0.0007231174253941123, 0.00040...
# 765   [0.08177920185060686, 0.0, 2.4954962964299485e...
# 1861  [0.0007599373806512638, 0.09524745379520932, 0...
# 113   [0.0, 0.0, 0.0, 0.03763527137627719, 0.0151334...
# 98    [5.711531917570147e-06, 0.0, 0.0, 0.0895029797...
# 1343  [0.0, 0.0, 0.0, 1.2186274411882736e-05, 6.6470...
# 1137  [0.0010908080023475013, 0.22031817538903856, 0...
# 9     [0.004467519328288835, 0.0, 0.0, 0.13238722517...
# 1081  [0.0, 0.010647907899918945, 7.620067340522062e...
# 1845  [0.015642853005707565, 0.028908041635957046, 0...
# 1450  [0.0, 2.79191672227006e-06, 0.0, 1.81474586947...
# 515   [0.05682613751625834, 0.0, 0.0, 0.101118402152...
# 311   [0.0, 0.0, 0.0, 0.006790282765689017, 3.237056...
# 1178  [4.564843510375045e-05, 0.07869988436559336, 0...
# 1650  [0.0, 0.056620310572775584, 0.0401089296073141...
# 1151  [0.0, 0.0, 0.0, 0.0025529727885361614, 0.00204...
# 300   [0.0004639166230817421, 1.1125098874861922e-06...
# 738   [1.3247978755172862e-05, 0.006094429174397488,...
# 1741  [9.910814801595911e-06, 0.09063909982094498, 0...
# 1190  [0.04448543517875714, 0.0016769264730050399, 0...
# 1017  [0.0, 0.0, 0.0, 5.762237788250445e-05, 0.00023...
# 254   [0.0, 0.0, 0.0, 0.044688175478531295, 0.001108...

# %%
representative_grids = [i for i in list(df.loc[selected]["grid_id"])]

# %%
df_points = pd.read_csv("points.csv")

# %%
df_points = df_points[df_points["index"].isin(representative_grids)].reset_index(drop=True)
df_points["index"] = range(len(df_points))
df_points["overall_status"] = False
df_points["download_status"] = False
df_points["model_status"] = False
df_points["segmentation_status"] = False
df_points["postprocessing_status"] = False
df_points["plantation_status"] = False

# %%
df_points
# Out:
#      index                                             points  overall_status  \
# 0        0  ((18.989414715239327, 78.81866455078125), (18....           False
# 1        1  ((18.989414715239327, 78.86260986328125), (18....           False
# 2        2  ((18.947855781294127, 78.81866455078125), (18....           False
# 3        3  ((18.947855781294127, 78.86260986328125), (18....           False
# 4        4  ((18.823116948090497, 78.55499267578125), (18....           False
# ..     ...                                                ...             ...
# 235    235  ((14.402759378194208, 79.03839111328125), (14....           False
# 236    236  ((14.36019115837039, 79.25811767578125), (14.3...           False
# 237    237  ((14.36019115837039, 79.30206298828125), (14.3...           False
# 238    238  ((14.317614840171906, 79.25811767578125), (14....           False
# 239    239  ((14.317614840171906, 79.30206298828125), (14....           False
#
#      download_status  model_status  segmentation_status  \
# 0              False         False                False
# 1              False         False                False
# 2              False         False                False
# 3              False         False                False
# 4              False         False                False
# ..               ...           ...                  ...
# 235            False         False                False
# 236            False         False                False
# 237            False         False                False
# 238            False         False                False
# 239            False         False                False
#
#      postprocessing_status  plantation_status
# 0                    False              False
# 1                    False              False
# 2                    False              False
# 3                    False              False
# 4                    False              False
# ..                     ...                ...
# 235                  False              False
# 236                  False              False
# 237                  False              False
# 238                  False              False
# 239                  False              False
#
# [240 rows x 8 columns]

# %%
df_points.to_csv("status.csv", index=False)
