# %%
import ee
ee.Authenticate() #Uncomment this whenever needed, once done usually not needed for 1-2 days
ee.Initialize(project='raman-461708')
import geemap

masalia_boundaries = ee.FeatureCollection("projects/ee-corestackdev/assets/apps/mws/jharkhand/dumka/masalia/lulc_v4_dumka_masalia_boundaries")
masalia_roi = ee.FeatureCollection("projects/ee-corestackdev/assets/apps/mws/jharkhand/dumka/masalia/filtered_mws_dumka_masalia_uid")

import re
original_lulc_img = ee.Image('projects/corestack-datasets/assets/datasets/LULC_v3_river_basin/pan_india_lulc_v3_2023_2024').select('predicted_label')
PARENT = 'projects/raman-461708/assets'

# ---- List all image assets once (fast follow-up lookups) ----
def _basename(asset_name: str) -> str:
    return asset_name.split('/')[-1]

all_assets = ee.data.listAssets({'parent': PARENT}).get('assets', [])
image_assets = [a for a in all_assets if a.get('type','').lower() == 'image']
basenames = {_basename(a['name']) for a in image_assets}

def asset_exists_base(base: str) -> bool:
    return base in basenames

def fullpath(base: str) -> str:
    return f'{PARENT}/{base}'

def list_part_bases_for_aez(aez_no: int):
    """Return sorted basenames for all parts like AEZ_{n}_v4_local_partK (K numeric)."""
    rx = re.compile(rf'^AEZ_{aez_no}_v4_local_part(\d+)$')
    parts = []
    for b in basenames:
        m = rx.match(b)
        if m:
            parts.append((int(m.group(1)), b))
    # Sort by numeric suffix to keep deterministic order (not required for mosaic, but nice to have).
    parts.sort(key=lambda x: x[0])
    return [b for _, b in parts]

def choose_assets_for_aez(aez_no: int):
    """
    Preference:
      1) AEZ_{n}_v4
      2) AEZ_{n}_v4_local_part*
      3) AEZ_{n}_v4_local
    Returns: list of full asset IDs (possibly multiple if parts), plus a metadata dict.
    """
    base_v4 = f'AEZ_{aez_no}_v4'
    base_local = f'AEZ_{aez_no}_v4_local'
    part_bases = list_part_bases_for_aez(aez_no)

    if asset_exists_base(base_v4):
        return [fullpath(base_v4)], {'source':'v4','parts':[]}

    if part_bases:
        return [fullpath(b) for b in part_bases], {'source':'v4_local_parts','parts':part_bases}

    if asset_exists_base(base_local):
        return [fullpath(base_local)], {'source':'v4_local','parts':[]}

    return [], {'source':'missing','parts':[]}

# ---- Collect images AEZ 1..19 ----
images = []
report = {}   # aez_no -> {'source':..., 'parts':[...] }
missing = []

for aez_no in range(1, 20):
    asset_ids, meta = choose_assets_for_aez(aez_no)
    report[aez_no] = meta
    if asset_ids:
        # If this AEZ has multiple parts, add them all; mosaic will merge them.
        for aid in asset_ids:
            images.append(ee.Image(aid))
    else:
        missing.append(aez_no)

if not images:
    raise RuntimeError("No AEZ images found across v4 / v4_local_parts / v4_local")

# ---- Final mosaic across all gathered images ----
# Order: AEZ 1..19; within an AEZ, parts in ascending numeric order.
# ImageCollection.mosaic() draws later images on top of earlier ones.
mosaic_img = ee.ImageCollection(images).mosaic()
m = geemap.Map()
#m.centerObject(farm.limit(1))


url = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}'
m.layout.height = '1000px'
m.add_tile_layer(url, name="Google Map", attribution="Google")
#m.add_basemap(, )
m.addLayerControl()
#m.addLayer(fields_boundary, {}, 'Fields')

palette = [
    '303000', '000000', '000000', '000000', '000000', 'f75cff', 
    '991695', 'e6ab2c', '3bef34', '2baa25', 'e6ef34', 'a1a524', 'eea15e'
]

palette_corrected = [
    '303000', '000000', '000000', '000000', '000000', 'f75cff', 
    '991695', 'e6ab2c', '3bef34', '2baa25', 'e6ef34', 'a1a524', 'eea15e', '29554E'
]

vis_params = {
    'min': 0,
    'max': 12,
    'palette': palette
}

vis_params_corrected = {
    'min': 0,
    'max': 13,
    'palette': palette_corrected
}

labels = """0. Background
1. Built-up
2. Water (Kharif)
3. Water (Kharif + Rabi)
4. Water (Kharif + Rabi + Zaid)
5. Croplands
6. Tree/Forest
7. Barren Land
8. Single Kharif (Light blue)
9. Single Non-Kharif
10. Double (Dark-Blue)
11. Triple
12. Shrub_Scrub
13. Plantation"""
labels = [i.split(". ")[-1] for i in labels.split("\n")]

palette_ = ['3bef34', '991695', '0000FF']
vis_params_ = {
    'min': 0,
    'max': 2,
    'palette': palette_
}
aez = ee.FeatureCollection("users/mtpictd/agro_eco_regions")

m.addLayer(mosaic_img.select("predicted_label"), vis_params_corrected, 'LULC_corrected')
m.addLayer(original_lulc_img, vis_params, 'LULC_original')
m.addLayer(aez, {}, "AEZ boundaries")
m.addLayer(masalia_roi, {}, "Masalia ROI")
m.addLayer(masalia_boundaries, {}, "Masalia Boundaries")
m
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
from pathlib import PurePosixPath

ROOT = 'projects/ee-corestackdev/assets/apps/mws'  # mws root

def list_children(parent):
    """Generator over immediate children of an EE asset folder, with paging."""
    page_token = None
    while True:
        resp = ee.data.listAssets({'parent': parent, 'pageSize': 1000, 'pageToken': page_token})
        for a in resp.get('assets', []):
            yield a
        page_token = resp.get('nextPageToken')
        if not page_token:
            break

def walk_folders(root):
    """Depth-first traversal over folders under root, yielding every asset."""
    stack = [root]
    while stack:
        parent = stack.pop()
        for a in list_children(parent):
            typ = a.get('type', '')
            name = a.get('name')  # full path like 'projects/.../assets/apps/mws/...'
            if typ.upper() == 'FOLDER':
                stack.append(name)
            else:
                yield a

def parse_mws_path(full_name):
    """
    Parse paths like:
    projects/ee-corestackdev/assets/apps/mws/<state>/<district>/<block>/filtered_mws_<state>_<block>_uid
    Return (state, district, block, basename) or None if it doesn't fit.
    """
    # Normalize to the part after /assets/
    try:
        # Split at '/assets/' to get the logical asset path
        logical = full_name.split('/assets/', 1)[1]
    except IndexError:
        return None
    parts = PurePosixPath(logical).parts  # ('apps','mws','<state>','<district>','<block>','filtered_mws_...')

    if len(parts) < 6 or parts[0] != 'apps' or parts[1] != 'mws':
        return None

    state, district, block = parts[2], parts[3], parts[4]
    basename = parts[-1]

    # Must start with filtered_mws_ and end with _uid and match state/block in name
    if not (basename.startswith('filtered_mws_') and basename.endswith('_uid')):
        return None

    # Expect exactly: filtered_mws_<state>_<block>_uid
    expected = f'filtered_mws_{district}_{block}_uid'
    if basename != expected:
        return None

    return state, district, block, basename

def find_filtered_mws_assets(root=ROOT):
    matches = []
    for asset in walk_folders(root):
        name = asset.get('name')  # canonical path
        print(name)
        parsed = parse_mws_path(name)
        if parsed:
            state, district, block, basename = parsed
            matches.append({
                'full_path': name,
                'state': state,
                'district': district,
                'block': block,
                'asset_type': asset.get('type'),
            })
    return matches

results = find_filtered_mws_assets(ROOT)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# projects/ee-corestackdev/assets/apps/mws/indian_state_boundaries
# projects/ee-corestackdev/assets/apps/mws/west_bengal/west_bengal_lithology
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/ET_annual_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/ET_fortnight_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/ET_fortnight_south_twenty-four_parganas_kakdwip_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/ET_fortnight_south_twenty-four_parganas_kakdwip_2022_2024
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/Prec_annual_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/Prec_fortnight_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/Runoff_annual_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/Runoff_fortnight_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/admin_boundary_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/aquifer_vector_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_south_twenty-four_parganas_kakdwip_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_south_twenty-four_parganas_kakdwip_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_south_twenty-four_parganas_kakdwip_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_south_twenty-four_parganas_kakdwip_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_south_twenty-four_parganas_kakdwip_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_vector_south_twenty-four_parganas_kakdwip_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_vector_south_twenty-four_parganas_kakdwip_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_vector_south_twenty-four_parganas_kakdwip_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_vector_south_twenty-four_parganas_kakdwip_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/change_vector_south_twenty-four_parganas_kakdwip_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/clart_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/crop_gridXlulc_south_twenty-four_parganas_kakdwip_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/crop_grid_south_twenty-four_parganas_kakdwip_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/cropping_intensity_south_twenty-four_parganas_kakdwip_2017-23
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/deltaG_fortnight_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/deltaG_well_depth_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/drainage_density_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/drainage_lines_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/drought_south_twenty-four_parganas_kakdwip_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/filtered_delta_g_annual_south_twenty-four_parganas_kakdwip_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/filtered_delta_g_fortnight_south_twenty-four_parganas_kakdwip_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/filtered_mws_south_twenty-four_parganas_kakdwip_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/lulc_vector_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/nrega_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/restoration_south_twenty-four_parganas_kakdwip_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/restoration_south_twenty-four_parganas_kakdwip_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/soge_vector_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/south_twenty-four_parganas_kakdwip_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/stream_order_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/stream_order_south_twenty-four_parganas_kakdwip_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/stream_order_south_twenty-four_parganas_kakdwip_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/swb1_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/swb2_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/terrain_raster_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_raster_south_twenty-four_parganas_kakdwip_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ccd_vector_south_twenty-four_parganas_kakdwip_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_raster_south_twenty-four_parganas_kakdwip_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_raster_south_twenty-four_parganas_kakdwip_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_raster_south_twenty-four_parganas_kakdwip_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_raster_south_twenty-four_parganas_kakdwip_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_raster_south_twenty-four_parganas_kakdwip_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_ch_vector_south_twenty-four_parganas_kakdwip_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_overall_change_raster_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/tree_health_overall_change_vector_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/well_depth_annual_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/south_twenty-four_parganas/kakdwip/well_depth_net_value_south_twenty-four_parganas_kakdwip
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/ET_annual_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/ET_fortnight_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/ET_fortnight_puruliya_raghunathpur_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/ET_fortnight_puruliya_raghunathpur_2022_2025
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/Prec_annual_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/Prec_fortnight_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/Runoff_annual_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/Runoff_fortnight_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/admin_boundary_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/aquifer_vector_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_puruliya_raghunathpur_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_puruliya_raghunathpur_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_puruliya_raghunathpur_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_puruliya_raghunathpur_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_puruliya_raghunathpur_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_vector_puruliya_raghunathpur_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_vector_puruliya_raghunathpur_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_vector_puruliya_raghunathpur_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_vector_puruliya_raghunathpur_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/change_vector_puruliya_raghunathpur_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/clart_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/crop_gridXlulc_puruliya_raghunathpur_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/crop_grid_puruliya_raghunathpur_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/cropping_intensity_puruliya_raghunathpur_2017-23
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/deltaG_fortnight_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/deltaG_well_depth_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drainage_density_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drainage_lines_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/drought_puruliya_raghunathpur_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/filtered_delta_g_annual_puruliya_raghunathpur_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/filtered_delta_g_fortnight_puruliya_raghunathpur_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/filtered_mws_puruliya_raghunathpur_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/lulc_vector_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/nrega_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_lulcXslopes_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/puruliya_raghunathpur_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/restoration_puruliya_raghunathpur_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/restoration_puruliya_raghunathpur_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/soge_vector_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/stream_order_puruliya_raghunathpur_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/stream_order_puruliya_raghunathpur_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/swb1_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/swb2_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/terrain_raster_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_raster_puruliya_raghunathpur_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ccd_vector_puruliya_raghunathpur_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_raster_puruliya_raghunathpur_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_raster_puruliya_raghunathpur_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_raster_puruliya_raghunathpur_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_raster_puruliya_raghunathpur_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_raster_puruliya_raghunathpur_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_ch_vector_puruliya_raghunathpur_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_overall_change_raster_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/tree_health_overall_change_vector_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/well_depth_annual_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/puruliya/raghunathpur/well_depth_net_value_puruliya_raghunathpur
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/ET_annual_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/ET_fortnight_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/ET_fortnight_purba_medinipur_tamluk_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/ET_fortnight_purba_medinipur_tamluk_2022_2024
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/Prec_annual_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/Prec_fortnight_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/Runoff_annual_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/Runoff_fortnight_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/admin_boundary_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/aquifer_vector_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_purba_medinipur_tamluk_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_purba_medinipur_tamluk_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_purba_medinipur_tamluk_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_purba_medinipur_tamluk_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_purba_medinipur_tamluk_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_vector_purba_medinipur_tamluk_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_vector_purba_medinipur_tamluk_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_vector_purba_medinipur_tamluk_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_vector_purba_medinipur_tamluk_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/change_vector_purba_medinipur_tamluk_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/crop_gridXlulc_purba_medinipur_tamluk_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/crop_grid_purba_medinipur_tamluk_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/cropping_intensity_purba_medinipur_tamluk_2017-23
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/drainage_density_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/drainage_density_purba_medinipur_tamluk1
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/drainage_lines_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/drought_purba_medinipur_tamluk_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/filtered_delta_g_annual_purba_medinipur_tamluk_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/filtered_delta_g_fortnight_purba_medinipur_tamluk_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/filtered_mws_purba_medinipur_tamluk_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/lulc_vector_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_clart_fes
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/purba_medinipur_tamluk_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/restoration_purba_medinipur_tamluk_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/restoration_purba_medinipur_tamluk_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/soge_vector_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/stream_order_purba_medinipur_tamluk_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/stream_order_purba_medinipur_tamluk_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/swb1_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/swb2_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/terrain_raster_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ccd_raster_purba_medinipur_tamluk_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ch_raster_purba_medinipur_tamluk_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ch_raster_purba_medinipur_tamluk_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ch_raster_purba_medinipur_tamluk_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ch_raster_purba_medinipur_tamluk_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_ch_raster_purba_medinipur_tamluk_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_overall_change_raster_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/tree_health_overall_change_vector_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/well_depth_annual_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/purba_medinipur/tamluk/well_depth_net_value_purba_medinipur_tamluk
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/ET_annual_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/ET_fortnight_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/ET_fortnight_north_twenty-four_parganas_basirhat_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/ET_fortnight_north_twenty-four_parganas_basirhat_2022_2025
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/Prec_annual_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/Prec_fortnight_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/Runoff_annual_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/Runoff_fortnight_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/admin_boundary_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/aquifer_vector_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_north_twenty-four_parganas_basirhat_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_north_twenty-four_parganas_basirhat_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_north_twenty-four_parganas_basirhat_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_north_twenty-four_parganas_basirhat_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_north_twenty-four_parganas_basirhat_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_vector_north_twenty-four_parganas_basirhat_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_vector_north_twenty-four_parganas_basirhat_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_vector_north_twenty-four_parganas_basirhat_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_vector_north_twenty-four_parganas_basirhat_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/change_vector_north_twenty-four_parganas_basirhat_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/clart_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/crop_gridXlulc_north_twenty-four_parganas_basirhat_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/crop_grid_north_twenty-four_parganas_basirhat_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/cropping_intensity_north_twenty-four_parganas_basirhat_2017-23
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/deltaG_fortnight_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/deltaG_well_depth_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drainage_density_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drainage_lines_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/drought_north_twenty-four_parganas_basirhat_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/filtered_delta_g_annual_north_twenty-four_parganas_basirhat_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/filtered_delta_g_fortnight_north_twenty-four_parganas_basirhat_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/filtered_mws_north_twenty-four_parganas_basirhat_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/lulc_vector_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/north_twenty-four_parganas_basirhat_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/nrega_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/restoration_north_twenty-four_parganas_basirhat_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/restoration_north_twenty-four_parganas_basirhat_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/soge_vector_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/stream_order_north_twenty-four_parganas_basirhat_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/stream_order_north_twenty-four_parganas_basirhat_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/swb1_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/swb2_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/terrain_raster_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_raster_north_twenty-four_parganas_basirhat_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_vector_north_twenty-four_parganas_basirhat_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_vector_north_twenty-four_parganas_basirhat_2017_2023
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_vector_north_twenty-four_parganas_basirhat_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ccd_vector_north_twenty-four_parganas_basirhat_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_raster_north_twenty-four_parganas_basirhat_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_raster_north_twenty-four_parganas_basirhat_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_raster_north_twenty-four_parganas_basirhat_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_raster_north_twenty-four_parganas_basirhat_2020
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_raster_north_twenty-four_parganas_basirhat_2021
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_vector_north_twenty-four_parganas_basirhat_2017
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_vector_north_twenty-four_parganas_basirhat_2017_2023
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_vector_north_twenty-four_parganas_basirhat_2018
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_ch_vector_north_twenty-four_parganas_basirhat_2019
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_overall_change_raster_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/tree_health_overall_change_vector_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/well_depth_annual_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/north_twenty-four_parganas/basirhat/well_depth_net_value_north_twenty-four_parganas_basirhat
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/ET_annual_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/ET_fortnight_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/ET_fortnight_darjiling_siliguri_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/ET_fortnight_darjiling_siliguri_2022_2024
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/Prec_annual_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/Prec_fortnight_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/Runoff_annual_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/Runoff_fortnight_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/admin_boundary_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/aquifer_vector_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_darjiling_siliguri_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_darjiling_siliguri_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_darjiling_siliguri_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_darjiling_siliguri_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_darjiling_siliguri_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_vector_darjiling_siliguri_Afforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_vector_darjiling_siliguri_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_vector_darjiling_siliguri_Deforestation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_vector_darjiling_siliguri_Degradation
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/change_vector_darjiling_siliguri_Urbanization
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/clart_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/crop_gridXlulc_darjiling_siliguri_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/crop_grid_darjiling_siliguri_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/cropping_intensity_darjiling_siliguri_2017-23
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_lulcXslopes_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/darjiling_siliguri_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/deltaG_fortnight_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/deltaG_well_depth_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/drainage_density_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/drainage_lines_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/drought_darjiling_siliguri_2017_2022
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/filtered_delta_g_annual_darjiling_siliguri_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/filtered_delta_g_fortnight_darjiling_siliguri_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/filtered_mws_darjiling_siliguri_uid
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/lulc_vector_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/restoration_darjiling_siliguri_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/restoration_darjiling_siliguri_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/soge_vector_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/stream_order_darjiling_siliguri
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/stream_order_darjiling_siliguri_raster
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/stream_order_darjiling_siliguri_vector
# projects/ee-corestackdev/assets/apps/mws/west_bengal/darjiling/siliguri/swb1_darjiling_siliguri
# ...
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/soge_vector_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/stream_order_ananthapur_nambulipulikunta_raster
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/stream_order_ananthapur_nambulipulikunta_vector
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/swb1_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/swb2_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/swb3_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/terrain_raster_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_raster_ananthapur_nambulipulikunta_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ccd_vector_ananthapur_nambulipulikunta_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_raster_ananthapur_nambulipulikunta_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_raster_ananthapur_nambulipulikunta_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_raster_ananthapur_nambulipulikunta_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_raster_ananthapur_nambulipulikunta_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_raster_ananthapur_nambulipulikunta_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_vector_ananthapur_nambulipulikunta_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_vector_ananthapur_nambulipulikunta_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_vector_ananthapur_nambulipulikunta_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_vector_ananthapur_nambulipulikunta_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_ch_vector_ananthapur_nambulipulikunta_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_overall_change_raster_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/tree_health_overall_change_vector_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/well_depth_annual_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/ananthapur/nambulipulikunta/well_depth_net_value_ananthapur_nambulipulikunta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/anantapur_lithology
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/ET_annual_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/ET_fortnight_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/Prec_annual_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/Prec_fortnight_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/Runoff_annual_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/Runoff_fortnight_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/admin_boundary_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_drought_0-30_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_lulcXplains_clusters
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_lulcXslopes_clusters
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/anantapur_nallacheruvu_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/change_anantapur_nallacheruvu_Afforestation
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/change_anantapur_nallacheruvu_CropIntensity
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/change_anantapur_nallacheruvu_Deforestation
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/change_anantapur_nallacheruvu_Degradation
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/change_anantapur_nallacheruvu_Urbanization
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/clart_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/clart_anantapur_nallacheruvu_1
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/crop_grid_anantapur_nallacheruvu_with_uid_16ha
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/crop_grid_ananthapur_nallacheruvu_with_uid_16ha_test
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/cropping_intensity_anantapur_nallacheruvu_2017-23
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drainage_density_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2017_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/drought_anantapur_nallacheruvu_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/filtered_delta_g_annual_anantapur_nallacheruvu_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/filtered_delta_g_fortnight_anantapur_nallacheruvu_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/filtered_mws_anantapur_nallacheruvu_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/swb1_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/swb2_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/swb3_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/terrain_raster_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/well_depth_annual_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/nallacheruvu/well_depth_net_value_anantapur_nallacheruvu
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/ET_annual_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/ET_fortnight_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/Prec_annual_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/Prec_fortnight_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/Runoff_annual_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/Runoff_fortnight_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2017-07-01_2018-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2017-07-01_2018-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2018-07-01_2019-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2018-07-01_2019-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2019-07-01_2020-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2019-07-01_2020-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2020-07-01_2021-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2020-07-01_2021-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2021-07-01_2022-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2021-07-01_2022-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2022-07-01_2023-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2022-07-01_2023-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2023-07-01_2024-06-30_LULCmap_10m
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_2023-07-01_2024-06-30_LULCmap_10m_v2
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_drought_0-30_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/anantapur_gandlapenta_terrain_clusters
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/cropping_intensity_anantapur_gandlapenta_2017-23
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2017
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2017_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2018
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2019
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2020
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2021
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/drought_anantapur_gandlapenta_2022
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/filtered_delta_g_annual_anantapur_gandlapenta_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/filtered_delta_g_fortnight_anantapur_gandlapenta_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/filtered_mws_anantapur_gandlapenta_uid
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/swb1_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/swb2_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/swb3_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/well_depth_annual_anantapur_gandlapenta
# projects/ee-corestackdev/assets/apps/mws/andhra_pradesh/anantapur/gandlapenta/well_depth_net_value_anantapur_gandlapenta

# %%
results_pats = [i["full_path"] for i in results]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
merged_fc = []
# Start with an empty placeholder
merged_fc = ee.FeatureCollection([])

for i, path in enumerate(results_pats, 1):
    fc = ee.FeatureCollection(path)

    # Optionally tag each feature with its source path
    fc = fc.map(lambda f: f.set('source_path', path))

    # Merge with the growing collection
    merged_fc = merged_fc.merge(fc)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m.addLayer(merged_fc, {}, "All MWS filtered UIDs")
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=919586.0, center=[21.70017946130734, 85.37243843078615], controls=(WidgetControl(options=['position…

# %%
source_path: projects/ee-corestackdev/assets/apps/mws/karnataka/chik_ballapur/chintamani/filtered_mws_chik_ballapur_chintamani_uid

# %%
# Threshold rule: use > 0.5 for "more than 50%". Change to gte if you want ">= 50%".
USE_STRICT_GT = True  # True => > 0.5 ; False => >= 0.5

# Class groups (by your schema)
FARM_CLASSES = [8, 9, 10, 11]
SCRUB_CLASSES = [12, 7]
FOREST_CLASS  = [6]
PLANTATION    = [13]

# ---- INIT ----
ee.Initialize()

lulc = mosaic_img.select("predicted_label").clip(masalia_roi).rename('lulc').toInt()
bounds = masalia_boundaries.filter(ee.Filter.neq("class", "plantation"))

# Ensure we only count pixels where LULC exists (mask area by LULC mask)
area_img = ee.Image.pixelArea().updateMask(lulc.mask()).rename('px_area')



# Reduce per polygon: sum(pixel area) grouped by LULC class
grouped = area_img.addBands(lulc).reduceRegions(
    collection=bounds,
    reducer=ee.Reducer.sum().group(groupField=1, groupName='class'),  # band 1 = 'lulc' (area is band 0)
    scale=10
)

def list_to_area_dict(group_list):
    group_list = ee.List(group_list)
    empty = ee.Dictionary({})
    def _acc(el, acc):
        el = ee.Dictionary(el)
        cls = ee.Number(el.get('class')).format()
        sm  = ee.Number(el.get('sum'))
        return ee.Dictionary(acc).set(cls, sm)
    return ee.Dictionary(group_list.iterate(_acc, empty))

def frac_for(f_area_dict, cls_ids, poly_area):
    cls_ids = ee.List(cls_ids)
    total = ee.Number(cls_ids.iterate(
        lambda c, acc: ee.Number(acc).add(ee.Number(f_area_dict.get(ee.Number(c).format(), 0))),
        0
    ))
    return ee.Algorithms.If(ee.Number(poly_area).gt(0), ee.Number(total).divide(poly_area), 0)

def classify_feature(f):
    f = ee.Feature(f)
    poly_area = f.geometry().area(maxError=1)

    # SAFE way to get the reducer output list `groups`
    raw_groups = f.get('groups')  # may be null
    groups = ee.List(ee.Algorithms.If(
        ee.Algorithms.IsEqual(raw_groups, None),
        ee.List([]),
        raw_groups
    ))

    area_dict = list_to_area_dict(groups)

    farm_frac   = ee.Number(frac_for(area_dict, [8,9,10,11], poly_area))
    scrubs_frac = ee.Number(frac_for(area_dict, [12,7],      poly_area))
    forest_frac = ee.Number(frac_for(area_dict, [6],         poly_area))
    plant_frac  = ee.Number(frac_for(area_dict, [13],        poly_area))

    thr = 0.5  # change to >= by swapping gt->gte
    label = ee.Algorithms.If(farm_frac.gt(thr),   'farm',
             ee.Algorithms.If(scrubs_frac.gt(thr),'scrubs',
             ee.Algorithms.If(forest_frac.gt(thr),'forest',
             ee.Algorithms.If(plant_frac.gt(thr), 'plantation', 'mixed'))))

    return f.set({
        'farm_frac': farm_frac,
        'scrubs_frac': scrubs_frac,
        'forest_frac': forest_frac,
        'plantation_frac': plant_frac,
        'label': label
    })


classified = grouped.map(classify_feature)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
classified.limit(1).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 classified.limit(1).getInfo()
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/collection.py:579, in Collection.getInfo(self)
#     566 def getInfo(self) -> Any | None:
#     567   """Returns all the known information about this collection.
#     568
#     569   This function makes a REST call to to retrieve all the known information
#    (...)    577          properties.
#     578   """
# --> 579   return super().getInfo()
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Any | None:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/data.py:1128, in computeValue(obj)
#    1125 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1126 _maybe_populate_workload_tag(body)
# -> 1128 return _execute_cloud_call(
#    1129     _get_cloud_projects()
#    1130     .value()
#    1131     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1132 )['result']
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/data.py:409, in _execute_cloud_call(call, num_retries)
#     407 num_retries = _max_retries if num_retries is None else num_retries
#     408 try:
# --> 409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
#     411   raise _translate_cloud_exception(e)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/_cloud_api_utils.py:71, in _Http.request(***failed resolving arguments***)
#      64 del redirections  # Ignored
#      66 try:
#      67   # googleapiclient is expecting an httplib2 object, and doesn't include
#      68   # requests error in the list of transient errors. Therefore, transient
#      69   # requests errors should be converted to kinds that googleapiclient
#      70   # consider transient.
# ---> 71   response = self._session.request(
#      72       method, uri, data=body, headers=headers, timeout=self._timeout
#      73   )
#      74 except requests.exceptions.ConnectionError as connection_error:
#      75   raise ConnectionError(connection_error) from connection_error
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
parts = lulc.reduceRegions(
    collection=bounds,
    reducer=ee.Reducer.frequencyHistogram(),  # returns a {class: count} dict
    scale=10
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
parts.limit(10).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
FARM_CLASSES = [8, 9, 10, 11]
SCRUB_CLASSES = [12, 7]
FOREST_CLASS  = [6]
PLANTATION    = [13]


lulc = mosaic_img.select("predicted_label").clip(masalia_roi).rename('lulc').toInt()
bounds = masalia_boundaries.filter(ee.Filter.neq("class", "plantation"))

def get_distribution(feature):
    feature = ee.Feature(feature)
    hist = lulc.reduceRegion(
        reducer=ee.Reducer.frequencyHistogram(),
        geometry=feature.geometry(),
        scale=10)
    
    # 2) Pull {class_str: count} from the 'lulc' band
    counts = ee.Dictionary(hist.get('lulc', ee.Dictionary({})))

    # 3) Total pixels inside this boundary
    total = ee.Number(
        ee.List(counts.values()).iterate(
            lambda v, acc: ee.Number(acc).add(ee.Number(v)),
            0
        )
    )

    # 4) Sum helper for a list of numeric class IDs (convert each to string key)
    def sum_classes(class_list):
        class_list = ee.List(class_list)
        def _acc(c, acc):
            key = ee.Number(c).format()                  # convert 8 -> "8"
            val = ee.Number(counts.get(key, 0))          # counts have string keys
            return ee.Number(acc).add(val)
        return ee.Number(class_list.iterate(_acc, 0))

    # 5) Compute farm % = classes 8,9,10,11 / total
    farm_count = sum_classes(FARM_CLASSES)
    plantation_count = sum_classes(PLANTATION)
    
    farm_pct = ee.Algorithms.If(ee.Number(total).gt(0), ee.Number(farm_count).divide(total).multiply(100), 0)
    plantation_pct = ee.Algorithms.If(ee.Number(total).gt(0), ee.Number(plantation_count).divide(total).multiply(100), 0)
    
    return feature.set('plantation_pct', farm_pct)


boundaries = bounds.map(get_distribution)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
boundaries.filter(ee.Filter.gt('plantation_pct', 50)).limit(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 boundaries.filter(ee.Filter.gt('plantation_pct', 50)).limit(10)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/IPython/core/displayhook.py:279, in DisplayHook.__call__(self, result)
#     277 self.start_displayhook()
#     278 self.write_output_prompt()
# --> 279 format_dict, md_dict = self.compute_format_data(result)
#     280 self.update_user_ns(result)
#     281 self.fill_exec_result(result)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/IPython/core/displayhook.py:164, in DisplayHook.compute_format_data(self, result)
#     134 def compute_format_data(self, result):
#     135     """Compute format data of the object to be displayed.
#     136
#     137     The format data is a generalization of the :func:`repr` of an object.
#    (...)    162
#     163     """
# --> 164     return self.shell.display_formatter.format(result)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/eerepr/repr.py:71, in _ee_repr(obj)
#      68 repr_func = _uncached_repr_html_ if _is_nondeterministic(obj) else _repr_html_
#      70 try:
# ---> 71     rep = repr_func(obj)
#      72 except ee.EEException as e:
#      73     if options.on_error == "raise":
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/eerepr/repr.py:46, in _repr_html_(obj)
#      44 """Generate an HTML representation of an EE object."""
#      45 # Escape all strings in object info to prevent injection
# ---> 46 info = escape_object(obj.getInfo())
#      47 body = convert_to_html(info)
#      49 return (
#      50     "<div>"
#      51     f"<style>{CSS}</style>"
#    (...)     55     "</div>"
#      56 )
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/collection.py:579, in Collection.getInfo(self)
#     566 def getInfo(self) -> Any | None:
#     567   """Returns all the known information about this collection.
#     568
#     569   This function makes a REST call to to retrieve all the known information
#    (...)    577          properties.
#     578   """
# --> 579   return super().getInfo()
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Any | None:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/data.py:1128, in computeValue(obj)
#    1125 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1126 _maybe_populate_workload_tag(body)
# -> 1128 return _execute_cloud_call(
#    1129     _get_cloud_projects()
#    1130     .value()
#    1131     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1132 )['result']
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/data.py:409, in _execute_cloud_call(call, num_retries)
#     407 num_retries = _max_retries if num_retries is None else num_retries
#     408 try:
# --> 409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
#     411   raise _translate_cloud_exception(e)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/ee/_cloud_api_utils.py:71, in _Http.request(***failed resolving arguments***)
#      64 del redirections  # Ignored
#      66 try:
#      67   # googleapiclient is expecting an httplib2 object, and doesn't include
#      68   # requests error in the list of transient errors. Therefore, transient
#      69   # requests errors should be converted to kinds that googleapiclient
#      70   # consider transient.
# ---> 71   response = self._session.request(
#      72       method, uri, data=body, headers=headers, timeout=self._timeout
#      73   )
#      74 except requests.exceptions.ConnectionError as connection_error:
#      75   raise ConnectionError(connection_error) from connection_error
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /media/disk3/raman/code/anaconda3/envs/raman/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import ee
ee.Authenticate() #Uncomment this whenever needed, once done usually not needed for 1-2 days
ee.Initialize(project='raman-461708')
import geemap

masalia_boundaries = ee.FeatureCollection("projects/ee-corestackdev/assets/apps/mws/jharkhand/dumka/masalia/lulc_v4_dumka_masalia_boundaries")
masalia_roi = ee.FeatureCollection("projects/ee-corestackdev/assets/apps/mws/jharkhand/dumka/masalia/filtered_mws_dumka_masalia_uid")

import re
original_lulc_img = ee.Image('projects/corestack-datasets/assets/datasets/LULC_v3_river_basin/pan_india_lulc_v3_2023_2024').select('predicted_label')
PARENT = 'projects/raman-461708/assets'

# ---- List all image assets once (fast follow-up lookups) ----
def _basename(asset_name: str) -> str:
    return asset_name.split('/')[-1]

all_assets = ee.data.listAssets({'parent': PARENT}).get('assets', [])
image_assets = [a for a in all_assets if a.get('type','').lower() == 'image']
basenames = {_basename(a['name']) for a in image_assets}

def asset_exists_base(base: str) -> bool:
    return base in basenames

def fullpath(base: str) -> str:
    return f'{PARENT}/{base}'

def list_part_bases_for_aez(aez_no: int):
    """Return sorted basenames for all parts like AEZ_{n}_v4_local_partK (K numeric)."""
    rx = re.compile(rf'^AEZ_{aez_no}_v4_local_part(\d+)$')
    parts = []
    for b in basenames:
        m = rx.match(b)
        if m:
            parts.append((int(m.group(1)), b))
    # Sort by numeric suffix to keep deterministic order (not required for mosaic, but nice to have).
    parts.sort(key=lambda x: x[0])
    return [b for _, b in parts]

def choose_assets_for_aez(aez_no: int):
    """
    Preference:
      1) AEZ_{n}_v4
      2) AEZ_{n}_v4_local_part*
      3) AEZ_{n}_v4_local
    Returns: list of full asset IDs (possibly multiple if parts), plus a metadata dict.
    """
    base_v4 = f'AEZ_{aez_no}_v4'
    base_local = f'AEZ_{aez_no}_v4_local'
    part_bases = list_part_bases_for_aez(aez_no)

    if asset_exists_base(base_v4):
        return [fullpath(base_v4)], {'source':'v4','parts':[]}

    if part_bases:
        return [fullpath(b) for b in part_bases], {'source':'v4_local_parts','parts':part_bases}

    if asset_exists_base(base_local):
        return [fullpath(base_local)], {'source':'v4_local','parts':[]}

    return [], {'source':'missing','parts':[]}

# ---- Collect images AEZ 1..19 ----
images = []
report = {}   # aez_no -> {'source':..., 'parts':[...] }
missing = []

for aez_no in range(1, 20):
    asset_ids, meta = choose_assets_for_aez(aez_no)
    report[aez_no] = meta
    if asset_ids:
        # If this AEZ has multiple parts, add them all; mosaic will merge them.
        for aid in asset_ids:
            images.append(ee.Image(aid))
    else:
        missing.append(aez_no)

if not images:
    raise RuntimeError("No AEZ images found across v4 / v4_local_parts / v4_local")

# ---- Final mosaic across all gathered images ----
# Order: AEZ 1..19; within an AEZ, parts in ascending numeric order.
# ImageCollection.mosaic() draws later images on top of earlier ones.
mosaic_img = ee.ImageCollection(images).mosaic()
m = geemap.Map()
#m.centerObject(farm.limit(1))


url = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}'
m.layout.height = '1000px'
m.add_tile_layer(url, name="Google Map", attribution="Google")
#m.add_basemap(, )
m.addLayerControl()
#m.addLayer(fields_boundary, {}, 'Fields')

palette = [
    '303000', '000000', '000000', '000000', '000000', 'f75cff', 
    '991695', 'e6ab2c', '3bef34', '2baa25', 'e6ef34', 'a1a524', 'eea15e'
]

palette_corrected = [
    '303000', '000000', '000000', '000000', '000000', 'f75cff', 
    '991695', 'e6ab2c', '3bef34', '2baa25', 'e6ef34', 'a1a524', 'eea15e', '29554E'
]

vis_params = {
    'min': 0,
    'max': 12,
    'palette': palette
}

vis_params_corrected = {
    'min': 0,
    'max': 13,
    'palette': palette_corrected
}

labels = """0. Background
1. Built-up
2. Water (Kharif)
3. Water (Kharif + Rabi)
4. Water (Kharif + Rabi + Zaid)
5. Croplands
6. Tree/Forest
7. Barren Land
8. Single Kharif (Light blue)
9. Single Non-Kharif
10. Double (Dark-Blue)
11. Triple
12. Shrub_Scrub
13. Plantation"""
labels = [i.split(". ")[-1] for i in labels.split("\n")]

palette_ = ['3bef34', '991695', '0000FF']
vis_params_ = {
    'min': 0,
    'max': 2,
    'palette': palette_
}
aez = ee.FeatureCollection("users/mtpictd/agro_eco_regions")

m.addLayer(mosaic_img.select("predicted_label"), vis_params_corrected, 'LULC_corrected')
m.addLayer(original_lulc_img, vis_params, 'LULC_original')
m.addLayer(aez, {}, "AEZ boundaries")
m.addLayer(masalia_roi, {}, "Masalia ROI")
m.addLayer(boundaries.filter(ee.Filter.gt('farm_pct', 50)), {}, "Masalia Boundaries")
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
result = boundaries.filter(ee.Filter.gt('farm_pct', 50))
result = boundaries.filter(ee.Filter.gt('plantation_pct', 50))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Choose the properties you want in the export
EXPORT_PROPS = [
    'class',
    'plantation_pct',
    # add any original boundary attributes you want to keep, e.g.:
    # 'id', 'name', 'village', ...
]

# Build a slimmed FeatureCollection with only the chosen properties + geometry
def _to_slim(f):
    f = ee.Feature(f)
    props = f.toDictionary(EXPORT_PROPS)  # only the ones we want
    return ee.Feature(f.geometry(), props)

slim = result.map(_to_slim)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Example asset path (new-style): projects/<your-project>/assets/<folder>/<name>
asset_id = 'projects/raman-461708/assets/masalia_plantation_boundaries'

task_asset = ee.batch.Export.table.toAsset(
    collection=slim,
    description='masalia_boundaries_plantation_gee_asset',
    assetId=asset_id
)
task_asset.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
task_geo = ee.batch.Export.table.toDrive(
    collection=slim,  # use simplified one if you made it
    description='masalia_farm_boundaries',
    folder='gee_exports',                 # change or set to None for root
    fileNamePrefix='masalia_farm_boundaries',
    fileFormat='GeoJSON')
task_geo.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
